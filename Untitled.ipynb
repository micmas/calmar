# %%
import module
await module.load('deepdisco/20251008')
import shutil, os
print("deepdisco:", shutil.which("deepdisco"))
print("DEEPDISCO_HOME:", os.environ.get("DEEPDISCO_HOME"))
print("DEEPDISCO_VENV:", os.environ.get("DEEPDISCO_VENV"))
# Out:
# deepdisco: None
# DEEPDISCO_HOME: None
# DEEPDISCO_VENV: None
